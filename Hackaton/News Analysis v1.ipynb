# %% [markdown]
# # O dataset
#
#
# O dataset foi criado com base em notícias em portais que são conhecidos, ou seja, não há tendência de distribuição de notícias falsas e outros portais que são conhecidos em divulgar notícias falsas.
#
# Os portais com notícias confiáveis foram:
#
#     g1.globo.com
#     hojeemdia.com.br
#
# Os portais não confiáveis foram retirados de um estudo feito por alunos da USP onde levaram em consideração alguns pontos (https://www.issoenoticia.com.br/artigo/projeto-da-usp-lista-10-maiores-sites-de-falsas-noticias-no-brasil). Escolhemos os dois que tem mais compatilhamentos:
#
#     jornalivre.com.br
#     ceticismopolitico.com.br
#     diariodobrasil.org
#
# **Conforme vamos ver em breve, o dataset é constituido por aproximadamente 50000 dados de reviews do IMDB, sendo 25000 dados para treino. Estes já foram pré processados e separados em reviews positivos (nota >=7) e negativos (<5).**
#
# ## O conjunto de dados
#
# Os dados estão estruturados da seguinte forma:
# - id: um identificador do review
# - sentimento: a classificação do review, sendo 0 negativo ou 1 positivo
# - review: o review em si
#
# ## Desenvolvimento do DataSet

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
jornalivre = pd.read_csv('data/jornalivre.csv', sep=',')
diariodobrasil = pd.read_csv('data/diariodobrasil.csv', sep=',')
ceticismopolitico = pd.read_csv('data/ceticismopolitico.csv', sep=',')
g1 = pd.read_csv('data/g1.csv', sep=',')
hojeemdia = pd.read_csv('data/hojeemdia.csv', sep=',')

# %%
print(jornalivre.columns)
print(diariodobrasil.columns)
print(ceticismopolitico.columns)
print(g1.columns)
print(hojeemdia.columns)
# Out:
# Index(['Unnamed: 0', 'title', 'url', 'datepost', 'summary'], dtype='object')
# Index(['Unnamed: 0', 'title', 'url', 'date', 'summary'], dtype='object')
# Index(['Unnamed: 0', 'title', 'url', 'date', 'summary'], dtype='object')
# Index(['Unnamed: 0', 'title', 'url', 'summary'], dtype='object')
# Index(['Unnamed: 0', 'title', 'url', 'date', 'excerpt'], dtype='object')

# %% [markdown]
# Vamos manter somente as colunas: title, url e summary.

# %%
jornalivre = jornalivre.drop(['Unnamed: 0', 'datepost'], axis=1)
diariodobrasil = diariodobrasil.drop(['Unnamed: 0', 'date'], axis=1)
ceticismopolitico = ceticismopolitico.drop(['Unnamed: 0', 'date'], axis=1)
g1 = g1.drop(['Unnamed: 0'], axis=1)
hojeemdia = hojeemdia.drop(['Unnamed: 0', 'date'], axis=1)

# %%
print(jornalivre.columns)
print(diariodobrasil.columns)
print(ceticismopolitico.columns)
print(g1.columns)
print(hojeemdia.columns)
# Out:
# Index(['title', 'url', 'summary'], dtype='object')
# Index(['title', 'url', 'summary'], dtype='object')
# Index(['title', 'url', 'summary'], dtype='object')
# Index(['title', 'url', 'summary'], dtype='object')
# Index(['title', 'url', 'excerpt'], dtype='object')

# %% [markdown]
# Agora, iremos ajustar o nome da coluna 'excerpt'da última tabela.

# %%
hojeemdia=hojeemdia.rename(columns = {'excerpt':'summary'})

# %%
print(jornalivre.columns)
print(diariodobrasil.columns)
print(ceticismopolitico.columns)
print(g1.columns)
print(hojeemdia.columns)
# Out:
# Index(['title', 'url', 'summary'], dtype='object')
# Index(['title', 'url', 'summary'], dtype='object')
# Index(['title', 'url', 'summary'], dtype='object')
# Index(['title', 'url', 'summary'], dtype='object')
# Index(['title', 'url', 'summary'], dtype='object')

# %% [markdown]
# Vamos criar um label para identificar qual veículo o texto faz parte. Mesmo que pela url é possível identificar, esta prática facilita a análise.

# %%
jornalivre['veículo'] = 'jornalivre'
diariodobrasil['veículo'] = 'diariodobrasil'
ceticismopolitico['veículo'] = 'ceticismopolitico'
g1['veículo'] = 'g1'
hojeemdia['veículo'] = 'hojeemdia'

# %% [markdown]
# ### Criando o DataSet FakeNews

# %%
fakenews = pd.concat([jornalivre, diariodobrasil, ceticismopolitico])

# %%
fakenews.shape
# Out:
# (26679, 4)

# %%
fakenews.head(5)
# Out:
#                                                title  \
# 0  Notícia de que Trump reconheceu Jerusalém como...
# 1  Estudo do Ministério da Fazenda aponta: Brasil...
# 2  Em entrevista, Meirelles expõe desmandos do go...
# 3  Marcelo Odebrecht volta pra casa em jatinho pa...
# 4  Ex-secretário da Saúde deixa escapar que hemat...
#
#                                                  url  \
# 0  https://jornalivre.com/2017/12/09/noticia-de-q...
# 1  https://jornalivre.com/2017/12/08/estudo-do-mi...
# 2  https://jornalivre.com/2017/12/08/em-entrevist...
# 3  https://jornalivre.com/2017/12/05/marcelo-odeb...
# 4  https://jornalivre.com/2017/12/04/ex-secretari...
#
#                                              summary     veículo
# 0  Segundo noticiou o Diário Nacional, a Vereador...  jornalivre
# 1  Um dos assuntos mais comentados desta semana f...  jornalivre
# 2  Informa o portal G1: Segundo a lenda de Robin ...  jornalivre
# 3  Em uma entrevista concedida à Exame, o Ministr...  jornalivre
# 4  Diante da Reforma da Previdência, tucanos faze...  jornalivre

# %%
fakenews.tail(5)
# Out:
#                                                   title  \
# 6730  Como identificar um esquerdista desonesto só p...
# 6731  A arquitetura de uma ditadura pelo controle “s...
# 6732  A maior de todas as lições aprendidas nas elei...
# 6733  Como os tontons maCUTs se organizam, e como de...
# 6734                         Enfim, o que é a esquerda?
#
#                                                     url  \
# 6730  https://ceticismopolitico.com/2010/11/02/como-...
# 6731  https://ceticismopolitico.com/2010/10/28/a-arq...
# 6732  https://ceticismopolitico.com/2010/10/20/a-mai...
# 6733  https://ceticismopolitico.com/2010/10/18/como-...
# 6734  https://ceticismopolitico.com/2010/10/16/enfim...
#
#                                                 summary            veículo
# 6730  O vídeo acima mostra o trailer de um ótimo fil...  ceticismopolitico
# 6731  A forma pela qual o PT está implementando a di...  ceticismopolitico
# 6732  Eu nunca acreditei que Serra poderia vencer es...  ceticismopolitico
# 6733  Em sequência ao post de ontem, onde citei a pa...  ceticismopolitico
# 6734  Várias vezes neo ateus se opõem ao que escrevo...  ceticismopolitico

# %% [markdown]
# Levando em consideração que todas essas notícias há indícios de FakeNews, iremos criar um label 'target' com valor 1, dizendo que estas ocorrências são fakenews.

# %%
fakenews['target'] = 1

# %%
fakenews.head(10)
# Out:
#                                                title  \
# 0  Notícia de que Trump reconheceu Jerusalém como...
# 1  Estudo do Ministério da Fazenda aponta: Brasil...
# 2  Em entrevista, Meirelles expõe desmandos do go...
# 3  Marcelo Odebrecht volta pra casa em jatinho pa...
# 4  Ex-secretário da Saúde deixa escapar que hemat...
# 5  ESCÂNDALO: Vereadora do PSOL monta mega-esquem...
# 6  Notícia de que Trump reconheceu Jerusalém como...
# 7  Estudo do Ministério da Fazenda aponta: Brasil...
# 8  Em entrevista, Meirelles expõe desmandos do go...
# 9  PSDB tenta engambelar eleitores com posicionam...
#
#                                                  url  \
# 0  https://jornalivre.com/2017/12/09/noticia-de-q...
# 1  https://jornalivre.com/2017/12/08/estudo-do-mi...
# 2  https://jornalivre.com/2017/12/08/em-entrevist...
# 3  https://jornalivre.com/2017/12/05/marcelo-odeb...
# 4  https://jornalivre.com/2017/12/04/ex-secretari...
# 5  https://jornalivre.com/2017/12/07/escandalo-ve...
# 6  https://jornalivre.com/2017/12/09/noticia-de-q...
# 7  https://jornalivre.com/2017/12/08/estudo-do-mi...
# 8  https://jornalivre.com/2017/12/08/em-entrevist...
# 9  https://jornalivre.com/2017/12/06/psdb-tenta-e...
#
#                                              summary     veículo  target
# 0  Segundo noticiou o Diário Nacional, a Vereador...  jornalivre       1
# 1  Um dos assuntos mais comentados desta semana f...  jornalivre       1
# 2  Informa o portal G1: Segundo a lenda de Robin ...  jornalivre       1
# 3  Em uma entrevista concedida à Exame, o Ministr...  jornalivre       1
# 4  Diante da Reforma da Previdência, tucanos faze...  jornalivre       1
# 5  A inflação é um imposto invisível. Quando o go...  jornalivre       1
# 6  Além de manterem bloqueados os bens de Aldemir...  jornalivre       1
# 7  Informa a Veja: A antropóloga e historiadora M...  jornalivre       1
# 8  O senador Telmário Mota é mesmo um brigão. Em ...  jornalivre       1
# 9  Preso desde 2015 em caráter preventivo e com u...  jornalivre       1

# %% [markdown]
# ## DataSet de RealNews

# %%
realnews = pd.concat([g1, hojeemdia])

# %%
realnews.shape
# Out:
# (28307, 4)

# %%
realnews.head()
# Out:
#                                                title  \
# 0  Maia diz que plenário da Câmara começará a deb...
# 1  Marun toma posse como ministro da Secretaria d...
# 2  General do Exército que fez críticas ao govern...
# 3  Reforma da Previdência: favorável a fechar que...
# 4  Alckmin usa discurso para iniciar polarização ...
#
#                                                  url  \
# 0  https://g1.globo.com/politica/noticia/maia-diz...
# 1  https://g1.globo.com/politica/noticia/marun-to...
# 2  https://g1.globo.com/politica/noticia/general-...
# 3  https://g1.globo.com/politica/noticia/reforma-...
# 4  http://g1.globo.com/politica/blog/blog-do-cama...
#
#                                              summary veículo
# 0  Maia diz que plenário da Câmara começará a deb...      g1
# 1  Marun toma posse como ministro da Secretaria d...      g1
# 2  General do Exército que fez críticas ao govern...      g1
# 3  Reforma da Previdência: favorável a fechar que...      g1
# 4  Alckmin usa discurso para iniciar polarização ...      g1

# %%
realnews.tail()
# Out:
#                                                   title  \
# 9995  Reale Jr diz que decisão de Maranhão é 'tiro n...
# 9996  Seis partidos pedirão cassação de Maranhão no ...
# 9997  Cunha: decisão de Maranhão é absurda, irrespon...
# 9998  Governistas do Senado comemoram decisão de Mar...
# 9999  Decisão de Maranhão cria ainda mais tumulto na...
#
#                                                     url  \
# 9995  /primeiro-plano/pol%C3%ADtica/reale-jr-diz-que...
# 9996  /primeiro-plano/pol%C3%ADtica/seis-partidos-pe...
# 9997  /primeiro-plano/pol%C3%ADtica/cunha-decis%C3%A...
# 9998  /primeiro-plano/pol%C3%ADtica/governistas-do-s...
# 9999  /primeiro-plano/pol%C3%ADtica/decis%C3%A3o-de-...
#
#                                                 summary    veículo
# 9995  Reale Jr diz que decisão de Maranhão é 'tiro n...  hojeemdia
# 9996  Seis partidos pedirão cassação de Maranhão no ...  hojeemdia
# 9997  Cunha: decisão de Maranhão é absurda, irrespon...  hojeemdia
# 9998  Governistas do Senado comemoram decisão de Mar...  hojeemdia
# 9999  Decisão de Maranhão cria ainda mais tumulto na...  hojeemdia

# %% [markdown]
# Criando o label 'target' = 0, significando que estas notícias são verdadeiras

# %%
realnews['target'] = 0

# %%
realnews.head()
# Out:
#                                                title  \
# 0  Maia diz que plenário da Câmara começará a deb...
# 1  Marun toma posse como ministro da Secretaria d...
# 2  General do Exército que fez críticas ao govern...
# 3  Reforma da Previdência: favorável a fechar que...
# 4  Alckmin usa discurso para iniciar polarização ...
#
#                                                  url  \
# 0  https://g1.globo.com/politica/noticia/maia-diz...
# 1  https://g1.globo.com/politica/noticia/marun-to...
# 2  https://g1.globo.com/politica/noticia/general-...
# 3  https://g1.globo.com/politica/noticia/reforma-...
# 4  http://g1.globo.com/politica/blog/blog-do-cama...
#
#                                              summary veículo  target
# 0  Maia diz que plenário da Câmara começará a deb...      g1       0
# 1  Marun toma posse como ministro da Secretaria d...      g1       0
# 2  General do Exército que fez críticas ao govern...      g1       0
# 3  Reforma da Previdência: favorável a fechar que...      g1       0
# 4  Alckmin usa discurso para iniciar polarização ...      g1       0

# %% [markdown]
# Agora vamos juntar as duas bases

# %%
news = pd.concat([fakenews,  realnews])

# %%
news.reset_index(drop=True)
# Out:
#                                                    title  \
# 0      Notícia de que Trump reconheceu Jerusalém como...
# 1      Estudo do Ministério da Fazenda aponta: Brasil...
# 2      Em entrevista, Meirelles expõe desmandos do go...
# 3      Marcelo Odebrecht volta pra casa em jatinho pa...
# 4      Ex-secretário da Saúde deixa escapar que hemat...
# 5      ESCÂNDALO: Vereadora do PSOL monta mega-esquem...
# 6      Notícia de que Trump reconheceu Jerusalém como...
# 7      Estudo do Ministério da Fazenda aponta: Brasil...
# 8      Em entrevista, Meirelles expõe desmandos do go...
# 9      PSDB tenta engambelar eleitores com posicionam...
# 10     Após Dilma entregar inflação na estratosfera, ...
# 11           Defesa de Lula leva mais uma surra no TRF-4
# 12     Notícia de que Trump reconheceu Jerusalém como...
# 13     Estudo do Ministério da Fazenda aponta: Brasil...
# 14     Em entrevista, Meirelles expõe desmandos do go...
# 15     Marcelo Odebrecht volta pra casa em jatinho pa...
# 16     Ex-secretário da Saúde deixa escapar que hemat...
# 17     Antropóloga foi obrigada a deixar Cuba só por ...
# 18     Senador da extrema esquerda, Telmário Mota col...
# 19     Marcelo Odebrecht volta pra casa em jatinho pa...
# 20     Ex-secretário da Saúde deixa escapar que hemat...
# 21     Cabral pode ser transferido para fora do RJ po...
# 22     Bendine pede desbloqueio de uma verdadeira for...
# 23     Governo pretende reduzir ainda mais o quadro d...
# 24     Notícia de que Trump reconheceu Jerusalém como...
# 25     Estudo do Ministério da Fazenda aponta: Brasil...
# 26     Em entrevista, Meirelles expõe desmandos do go...
# 54974  Maranhão: nossa decisão está baseada na Consti...   hojeemdia       0
# 54975  Gilmar Mendes diz que 'ninguém fica em cargo p...   hojeemdia       0
# 54976  Renan ameaça adiar votação de afastamento de D...   hojeemdia       0
# 54977  'Minha fala foi absurda, mas fuga de Cerveró n...   hojeemdia       0
# 54978  Ministra do STF descarta analisar ação movida ...   hojeemdia       0
# 54979  Grupos marcam protesto contra a anulação do im...   hojeemdia       0
# 54980  Renan Calheiros dá prosseguimento ao processo ...   hojeemdia       0
# 54981  Reale Jr diz que decisão de Maranhão é 'tiro n...   hojeemdia       0
# 54982  Seis partidos pedirão cassação de Maranhão no ...   hojeemdia       0
# 54983  Cunha: decisão de Maranhão é absurda, irrespon...   hojeemdia       0
# 54984  Governistas do Senado comemoram decisão de Mar...   hojeemdia       0
# 54985  Decisão de Maranhão cria ainda mais tumulto na...   hojeemdia       0
#
# [54986 rows x 5 columns]

# %% [markdown]
# # Pré processamento
#
# - Para melhor controle, faremos o pré processamento novamente dos dados para garantir que as tags HTML, espaços em branco e etc.

# %%
from nltk.stem import WordNetLemmatizer
import unicodedata
from nltk.corpus import stopwords
import nltk
from collections import Counter
import re
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
wordnet_lemmatizer = WordNetLemmatizer()

# %%
def review_to_words( raw_review ):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    # 1. Remove HTML
    review_text = BeautifulSoup(raw_review, "html5lib").get_text()
    #
    # 2. Remove non-letters        
    letters_only = re.sub("\W+", " ", review_text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().strip().split()  
    
    # 3.a remove accents from words
    words_2 = []
    for word in words:
        nfkd_form = unicodedata.normalize('NFKD', word)
        only_ascii = nfkd_form.encode('ASCII', 'ignore')
        word = only_ascii.decode('utf-8')
        words_2.append(word)
    
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("portuguese"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words_2 if not w in stops]   
    #
    # 6. Apply Lemma
    lemma = [wordnet_lemmatizer.lemmatize(t) for t in meaningful_words]
    # 7. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( lemma ))

# %% [markdown]
# ### Vamos juntar a coluna 'title' e 'summary' para começar a análise das palavras

# %%
news['title_summary'] = news['title'] + str(" ") + news['summary']

# %%
news.reset_index(drop=True)
# Out:
#                                                    title  \
# 0      Notícia de que Trump reconheceu Jerusalém como...
# 1      Estudo do Ministério da Fazenda aponta: Brasil...
# 2      Em entrevista, Meirelles expõe desmandos do go...
# 3      Marcelo Odebrecht volta pra casa em jatinho pa...
# 4      Ex-secretário da Saúde deixa escapar que hemat...
# 5      ESCÂNDALO: Vereadora do PSOL monta mega-esquem...
# 6      Notícia de que Trump reconheceu Jerusalém como...
# 7      Estudo do Ministério da Fazenda aponta: Brasil...
# 8      Em entrevista, Meirelles expõe desmandos do go...
# 9      PSDB tenta engambelar eleitores com posicionam...
# 10     Após Dilma entregar inflação na estratosfera, ...
# 17      Antropóloga foi obrigada a deixar Cuba só por ...
# 18      Senador da extrema esquerda, Telmário Mota col...
# 19      Marcelo Odebrecht volta pra casa em jatinho pa...
# 20      Ex-secretário da Saúde deixa escapar que hemat...
# 21      Cabral pode ser transferido para fora do RJ po...
# 22      Bendine pede desbloqueio de uma verdadeira for...
# 23      Governo pretende reduzir ainda mais o quadro d...
# 24      Notícia de que Trump reconheceu Jerusalém como...
# 25      Estudo do Ministério da Fazenda aponta: Brasil...
# 26      Em entrevista, Meirelles expõe desmandos do go...
# 27      Marcelo Odebrecht volta pra casa em jatinho pa...
# 28      Ex-secretário da Saúde deixa escapar que hemat...
# 29      PSDB envergonhado de reformas liberais perde a...
#                               ...
# 9970    Senado deve votar cassação de Delcídio Amaral ...
# 9971    Mesmo após revogação, PP quer aprovar suspensã...
# 9972    Calote põe em risco casa de Waldir Maranhão Ca...
# 9973    Filho de Maranhão é exonerado de Tribunal de C...
# 9974    Dilma propõe agência para desenvolver região f...
# 9975    Oposição articula derrubada de interino Oposiç...
# 9976    Fazenda vai acumular a Previdência Fazenda vai...
# 9977    Waldir Maranhão revoga ato em que anulou sessã...
# 9978    Janot quer que Gleisi, Paulo Bernardo e empres...
# 9979    Renan confirma sessão para votar afastamento d...
# 9980    Cassação de Delcídio é aprovada na CCJ; votaçã...
# 9981    Filho de Waldir Maranhão é exonerado do Tribun...
# 9982    DEM e PSD protocolam representação contra Wald...
# 9983    Projeto de lei cria mais cinco universidades f...
# 9984    Manifestantes protestam contra a anulação do i...
# 9985    Frente Brasil Popular e CUT chamam para atos e...
# 9986    Muro do impeachment é reerguido na Esplanada d...
# 9987    Cardozo admite reunião com Maranhão, mas nega ...
# 9988    Maranhão: nossa decisão está baseada na Consti...
# 9989    Gilmar Mendes diz que 'ninguém fica em cargo p...
# 9990    Renan ameaça adiar votação de afastamento de D...
# 9991    'Minha fala foi absurda, mas fuga de Cerveró n...
# 9992    Ministra do STF descarta analisar ação movida ...
# 9993    Grupos marcam protesto contra a anulação do im...
# 9994    Renan Calheiros dá prosseguimento ao processo ...
# 9995    Reale Jr diz que decisão de Maranhão é 'tiro n...
# 9996    Seis partidos pedirão cassação de Maranhão no ...
# 9997    Cunha: decisão de Maranhão é absurda, irrespon...
# 9998    Governistas do Senado comemoram decisão de Mar...
# 9999    Decisão de Maranhão cria ainda mais tumulto na...
# Name: title_summary, Length: 54986, dtype: object

# %% [markdown]
# ## Divisão das bases

# %% [markdown]
# Agora, como iremos treinar nossa base em um modelo supervisionado, precisamos quebrar a nossa base em treino e teste. A base já está balanceada, ou seja, não há necessidade de fazer este tipo de tratamento.

# %%
news = news.dropna(axis=0, how='any')
news.reset_index(drop=True)
news = news.sample(n=len(news))

# %%
y = news['target']

# %%
news.isnull().sum()
# Out:
# title            0
# url              0
# summary          0
# veículo          0
# target           0
# title_summary    0
# dtype: int64

# %%
news_train, news_test, y_train, y_test = train_test_split(news, y, test_size=0.33, random_state=42)

# %% [markdown]
# Iremos rodar a função review_to_words no dataset completo

# %%
#Get the number of reviews based on the dataframe column size
num_news = news_train["title_summary"].size

# Initialize an empty list to hold the clean reviews
clean_train_news = []

# Loop over each review; create an index i that goes from 0 to the length
# of the movie review list 
for i in tqdm(range( 0, num_news ), total= num_news):
    # Call our function for each one, and add the result to the list of
    #clean reviews
    clean_train_news.append( review_to_words( str(news_train["title_summary"].iloc[i]) ) )
# Out:
# 100%|██████████| 31760/31760 [01:46<00:00, 298.41it/s]

# %%
clean_train_news[0:2]
# Out:
# ['moro elogia projeto abuso autoridade aprovado senado moro elogia projeto abuso autoridade aprovado senadoha 7 me cristiana lobo',
#  'ministro justica diz juizes querem ter 20 minutos gloria ministro justica diz juizes querem ter 20 minutos gloria eugenio aragao criticou decisao barrou nomeacao governo visao ministro pais passando periodo psicose coletiva ha 2 ano politica']

# %% [markdown]
# ### Modelo Bag of Words com Tf-Idf

# %% [markdown]
# Usando o modelo gensim

# %%
from gensim.corpora.dictionary import Dictionary
from collections import defaultdict
import itertools


docs = [doc.split() for doc in clean_train_news]

# %%
dictionary = Dictionary(docs)

# %%
corpus = [dictionary.doc2bow(doc) for doc in docs]

# %% [markdown]
# Usaremos a library do sciki-learn para desenvolver o modelo

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000)

# %%
train_data = vectorizer.fit(clean_train_news)

# %%
train_data.vocabulary_
# Out:
# {'tona': 4678,
#  'economia': 1657,
#  'sabiam': 4280,
#  'atividades': 503,
#  'salarios': 4297,
#  'casos': 804,
#  'textos': 4643,
#  'dessas': 1472,
#  'critica': 1248,
#  'humanas': 2388,
#  'feia': 2073,
#  'inacreditavel': 2474,
#  'gosto': 2287,
#  'inacio': 2473,
#  'aprovacao': 407,
#  'irma': 2626,
#  'fenomeno': 2087,
#  'comite': 1007,
#  'privada': 3821,
#  'cruel': 1258,
#  'arrogante': 437,
#  'reducao': 4076,
#  'villa': 4915,
#  'janeiro': 2654,
#  'focado': 2147,
#  'aplica': 369,
#  'existencia': 1961,
#  'revoltados': 4216,
#  'seguintes': 4338,
#  'valor': 4834,
#  'totalitarismo': 4698,
#  'desembargador': 1452,
#  'suplicy': 4518,
#  'tornaram': 4686,
#  'inevitavel': 2518,
#  'entendeu': 1763,
#  'sentiu': 4374,
#  'modelos': 3111,
#  'pgr': 3616,
#  'digo': 1536,
#  'especifico': 1845,
#  'pmdb': 3644,
#  'nacional': 3188,
#  'agentes': 208,
#  'vermelho': 4893,
#  'pontos': 3676,
#  'lewandowski': 2811,
#  'enganar': 1745,
#  'aviso': 569,
#  'margem': 2964,
#  'honestidade': 2372,
#  'desta': 1474,
#  'racismo': 3992,
#  'juca': 2698,
#  'solto': 4477,
#  'procuradores': 3839,
#  'execucao': 1944,
#  'lope': 2873,
#  'mtst': 3163,
#  'cena': 827,
#  'dizia': 1618,
#  'marxistas': 2983,
#  'apoiado': 377,
#  'protestar': 3894,
#  'agressao': 217,
#  'dirigentes': 1564,
#  'democratica': 1396,
#  'irracionais': 2630,
#  'permanecer': 3581,
#  'tentativas': 4604,
#  'recife': 4048,
#  'chilique': 881,
#  'polemicas': 3667,
#  'rodrigo': 4240,
#  'definiu': 1364,
#  'aceitavel': 112,
#  'garcia': 2232,
#  '37': 58,
#  'inves': 2607,
#  'desmascara': 1461,
#  '2008': 25,
#  'abandonar': 84,
#  'claudia': 928,
#  'entrada': 1769,
#  'maus': 2997,
#  'apenas': 367,
#  'acusacoes': 143,
#  'relacionadas': 4113,
#  'independencia': 2495,
#  'gosta': 2283,
#  'esperar': 1851,
#  'peemedebista': 3530,
#  '14': 11,
#  'pinheiro': 3625,
#  'jogado': 2675,
#  'criminosos': 1236,
#  'maranhao': 2953,
#  'antecipada': 335,
#  'administrativa': 166,
#  'caminho': 748,
#  'militar': 3085,
#  'colombia': 968,
#  'parte': 3460,
#  'censurar': 831,
#  'recuo': 4066,
#  'programas': 3854,
#  'refutar': 4091,
#  'fonte': 2153,
#  'excelente': 1940,
#  'daqueles': 1308,
#  'obama': 3281,
#  'paula': 3501,
#  'ingenuo': 2532,
#  'problema': 3829,
#  'entrevistas': 1780,
#  'caluniosa': 742,
#  'negativo': 3214,
#  'documento': 1622,
#  'facam': 1994,
#  'perdido': 3564,
#  'impunidade': 2469,
#  'colocar': 966,
#  'senado': 4356,
#  'alegando': 243,
#  'criou': 1237,
#  'investigadores': 2615,
#  'si': 4410,
#  'revisao': 4211,
#  'aqui': 417,
#  'ibope': 2402,
#  'comemoracao': 984,
#  'gasta': 2238,
#  'demonstrar': 1406,
#  'colocou': 967,
#  'reforca': 4084,
#  'trabalham': 4703,
#  'pf': 3615,
#  'sugere': 4503,
#  'obrigado': 3291,
#  'aulas': 534,
#  'investir': 2620,
#  'leitao': 2777,
#  'volta': 4958,
#  'distritao': 1590,
#  'pesquisas': 3598,
#  'sujo': 4511,
#  'rejeitar': 4109,
#  'ta': 4551,
#  'mineiro': 3092,
#  'entretanto': 1778,
#  'craig': 1211,
#  'papel': 3438,
#  'iguais': 2423,
#  'darwinismo': 1314,
#  'reino': 4105,
#  'volume': 4962,
#  'presidencial': 3775,
#  'empreiteiras': 1720,
#  'assista': 468,
#  'correcao': 1188,
#  'valores': 4835,
#  'taxon': 4570,
#  'discordar': 1565,
#  'hipocrisia': 2350,
#  'buscar': 712,
#  'governos': 2295,
#  'totalitarios': 4697,
#  'indicadores': 2503,
#  'fundamentais': 2211,
#  'declarado': 1337,
#  'publicacao': 3925,
#  'quorum': 3988,
#  'imediato': 2440,
#  'completamente': 1016,
#  'sintese': 4438,
#  'chorar': 885,
#  'igualdade': 2425,
#  'romero': 4245,
#  'honestos': 2374,
#  'fechado': 2067,
#  'junior': 2715,
#  'david': 1317,
#  'colocando': 965,
#  'obras': 3287,
#  'valer': 4828,
#  'apanhar': 355,
#  'vender': 4866,
#  'zona': 4997,
#  'minimo': 3093,
#  'secretario': 4326,
#  'detido': 1492,
#  'discute': 1572,
#  'turismo': 4766,
#  'legitimidade': 2772,
#  'clube': 936,
#  'declara': 1334,
#  'g1': 2219,
#  'evolucao': 1932,
#  'ultimos': 4776,
#  'senso': 4366,
#  'logica': 2867,
#  'repasse': 4138,
#  'perto': 3594,
#  'danos': 1304,
#  'hoffmann': 2358,
#  'profissional': 3851,
#  'votaram': 4972,
#  'informado': 2529,
#  'realizado': 4023,
#  'acreditam': 136,
#  'coracao': 1179,
#  'liberdade': 2820,
#  'propos': 3879,
#  'agenda': 206,
#  'saul': 4320,
#  'richard': 4221,
#  'atibaia': 496,
#  'configura': 1067,
#  'prazo': 3736,
#  'roubo': 4261,
#  'desmascarar': 1463,
#  'governista': 2291,
#  'aceite': 113,
#  'jato': 2661,
#  'acordo': 132,
#  'ninguem': 3242,
#  'instancia': 2553,
#  'hasselmann': 2335,
#  'site': 4443,
#  'doria': 1638,
#  'receberam': 4035,
#  'quadro': 3946,
#  'laudo': 2757,
#  'narrativa': 3195,
#  'nisso': 3243,
#  'mostram': 3145,
#  'ministra': 3098,
#  'bilionario': 646,
#  'censura': 830,
#  'dimensao': 1540,
#  'agredida': 214,
#  'norma': 3256,
#  'pm': 3643,
#  'patetica': 3494,
#  'demolir': 1401,
#  'embustes': 1706,
#  'rouanet': 4259,
#  'tse': 4759,
#  'parcela': 3449,
#  'nazista': 3203,
#  'verdadeiros': 4882,
#  'implica': 2456,
#  'risco': 4230,
#  'requiao': 4159,
#  'eliseu': 1698,
#  'veiculos': 4850,
#  'delacoes': 1375,
#  'miguel': 3072,
#  'facil': 2000,
#  'ato': 508,
#  'sabendo': 4277,
#  'embuste': 1705,
#  'preco': 3745,
#  'impor': 2458,
#  'saco': 4281,
#  'observem': 3295,
#  'corrente': 1190,
#  'intuito': 2600,
#  'falha': 2017,
#  'existir': 1962,
#  'gayzista': 2244,
#  'daqui': 1309,
#  'expoe': 1973,
#  'totalmente': 4699,
#  'empresa': 1722,
#  'absoluta': 96,
#  'manifesto': 2938,
#  'programa': 3853,
#  'temer': 4587,
#  'collor': 962,
#  'outras': 3398,
#  'ante': 334,
#  'colegio': 957,
#  'alvos': 290,
#  'indicacao': 2501,
#  'revista': 4212,
#  'clique': 935,
#  'flavio': 2144,
#  'conselho': 1099,
#  'equivoco': 1797,
#  'esquerda': 1865,
#  'matar': 2988,
#  'wesley': 4984,
#  'recuperacao': 4067,
#  'emenda': 1707,
#  'pensa': 3540,
#  'atrair': 512,
#  'conversas': 1167,
#  'defender': 1347,
#  'envio': 1786,
#  'fachin': 1999,
#  'totalitarias': 4695,
#  'recibos': 4047,
#  'vantagem': 4839,
#  'gerar': 2262,
#  'moderna': 3115,
#  'doutrina': 1639,
#  'desarmamento': 1438,
#  'rotula': 4253,
#  'usadas': 4800,
#  'divisao': 1606,
#  'produto': 3843,
#  '150': 13,
#  'junto': 2717,
#  'picciani': 3621,
#  'condenados': 1056,
#  'espere': 1853,
#  'milicianos': 3078,
#  'pau': 3500,
#  'guido': 2324,
#  'justa': 2723,
#  'tao': 4563,
#  'fgts': 2096,
#  'lucio': 2882,
#  'bilhao': 644,
#  'responsaveis': 4174,
#  'massa': 2985,
#  'bruno': 704,
#  'realizacao': 4021,
#  'indignado': 2510,
#  'parcial': 3451,
#  'aspecto': 450,
#  'refuta': 4089,
#  'sul': 4513,
#  'atualmente': 525,
#  'adequado': 156,
#  'terminar': 4620,
#  'adeptos': 153,
#  'meia': 3012,
#  'pobre': 3646,
#  'revela': 4206,
#  'brasileiras': 695,
#  'manobras': 2942,
#  'marxista': 2982,
#  'soares': 4449,
#  'pimentel': 3624,
#  'russomanno': 4270,
#  'elogios': 1701,
#  'rebater': 4027,
#  'vinda': 4917,
#  'ocorre': 3308,
#  'pps': 3722,
#  'queiram': 3964,
#  'lideranca': 2829,
#  'autorizou': 552,
#  'autoriza': 550,
#  'maio': 2910,
#  'reunem': 4200,
#  'the': 4644,
#  'divulgada': 1609,
#  'lavagem': 2760,
#  'privilegiado': 3826,
#  'ocupar': 3319,
#  'cobra': 941,
#  'aumentam': 536,
#  'falacias': 2009,
#  'recomenda': 4055,
#  'assume': 472,
#  'randolfe': 3999,
#  'neve': 3238,
#  'acusa': 141,
#  'possui': 3706,
#  'expressar': 1978,
#  'lancou': 2753,
#  'decreta': 1341,
#  'prb': 3737,
#  'chegando': 875,
#  'diretorio': 1562,
#  'juntar': 2716,
#  'religiosos': 4131,
#  'proprio': 3887,
#  'apoiam': 379,
#  'sangue': 4308,
#  'tai': 4553,
#  'rebate': 4026,
#  'relacionado': 4114,
#  'perderam': 3562,
#  'calote': 740,
#  'formula': 2163,
#  'olhar': 3340,
#  'escrevi': 1830,
#  'falo': 2020,
#  'ligados': 2838,
#  'mora': 3127,
#  'psol': 3921,
#  'comando': 974,
#  'anticorrupcao': 342,
#  'comecam': 978,
#  'ver': 4873,
#  'leo': 2795,
#  'oas': 3280,
#  'critico': 1254,
#  'dependem': 1421,
#  'considerado': 1110,
#  'feria': 2088,
#  'garante': 2229,
#  'catolicos': 813,
#  'exatamente': 1937,
#  'educacao': 1670,
#  'portaria': 3686,
#  'resolveram': 4166,
#  'negociacao': 3216,
#  'foco': 2149,
#  'idiota': 2416,
#  'inicio': 2541,
#  'protesto': 3895,
#  'pericia': 3574,
#  'cujo': 1268,
#  'extremamente': 1985,
#  'executiva': 1946,
#  'vontade': 4963,
#  'tornado': 4682,
#  'motivo': 3151,
#  'madrugada': 2902,
#  'miller': 3087,
#  'indice': 2505,
#  'cirurgia': 906,
#  'esconder': 1821,
#  'humanistas': 2392,
#  'procedimento': 3831,
#  'ouve': 3402,
#  'monopolio': 3122,
#  'tirania': 4654,
#  'falei': 2016,
#  'mentais': 3036,
#  'serem': 4380,
#  'obvio': 3305,
#  'rogerio': 4243,
#  'roda': 4239,
#  'ditadura': 1595,
#  'caravana': 779,
#  'marco': 2962,
#  'passar': 3484,
#  'postou': 3713,
#  'henrique': 2344,
#  'ridicularizar': 4225,
#  'aparentemente': 362,
#  'catraca': 814,
#  'marido': 2968,
#  'fake': 2006,
#  'cultural': 1278,
#  'atea': 486,
#  'desempenho': 1453,
#  'diante': 1517,
#  'estados': 1877,
#  '28': 45,
#  'citei': 916,
#  'comportamental': 1022,
#  'coerente': 948,
#  'eletronicas': 1695,
#  'abrir': 94,
#  'exagero': 1934,
#  'moraes': 3129,
#  'radicais': 3995,
#  'pressionado': 3785,
#  '10': 6,
#  'documentos': 1623,
#  'guarda': 2320,
#  'simplesmente': 4428,
#  'sairam': 4290,
#  'ademais': 151,
#  'souza': 4486,
#  '00': 0,
#  'nogueira': 3248,
#  'indicia': 2506,
#  'faltou': 2027,
#  'validade': 4832,
#  'pragmatico': 3726,
#  'eduardo': 1669,
#  'desonesto': 1466,
#  'discutido': 1574,
#  'york': 4989,
#  'esforcos': 1835,
#  'rotular': 4256,
#  'curioso': 1287,
#  'coronel': 1182,
#  'britanico': 703,
#  'salvador': 4301,
#  'tomam': 4674,
#  'crer': 1218,
#  'maluco': 2919,
#  'unica': 4782,
#  'cassado': 806,
#  'cairam': 732,
#  'chantagem': 863,
#  'votacoes': 4967,
#  'militancia': 3082,
#  'dificuldades': 1530,
#  'pequeno': 3548,
#  'meios': 3014,
#  'queria': 3972,
#  'cientifico': 896,
#  'mudanca': 3165,
#  'pbh': 3508,
#  'lima': 2839,
#  'maiores': 2912,
#  'denuncia': 1411,
#  'uniao': 4781,
#  'optar': 3374,
#  'previdencia': 3800,
#  'aumento': 538,
#  'vanessa': 4838,
#  'indenizacao': 2494,
#  'prisao': 3819,
#  'missao': 3107,
#  'sindical': 4434,
#  'animal': 330,
#  'pleno': 3641,
#  'esforco': 1834,
#  'francisco': 2182,
#  'expor': 1974,
#  'estatuto': 1890,
#  'blogueiro': 657,
#  'licitacao': 2825,
#  'situacoes': 4446,
#  'milhares': 3076,
#  'acho': 122,
#  'linhas': 2851,
#  'pura': 3941,
#  'simulacao': 4429,
#  'seguro': 4347,
#  'cotidiano': 1205,
#  'ilegal': 2428,
#  'paragrafo': 3444,
#  'errou': 1802,
#  'mentiu': 3048,
#  'partidos': 3473,
#  'todos': 4666,
#  '19': 17,
#  'cidadania': 888,
#  'aceitacao': 110,
#  'meritos': 3056,
#  'psdb': 3913,
#  'jogou': 2682,
#  'dignidade': 1534,
#  'envolvido': 1790,
#  '26': 43,
#  'paginas': 3422,
#  'concedeu': 1040,
#  'negro': 3223,
#  'eleger': 1681,
#  'go': 2274,
#  'autoritarismo': 549,
#  'ontem': 3352,
#  'trouxeram': 4754,
#  'baiano': 574,
#  'familia': 2028,
#  'percebido': 3554,
#  'maquina': 2951,
#  'trabalhadores': 4702,
#  'salas': 4298,
#  'complica': 1019,
#  'legislacao': 2768,
#  'visitar': 4938,
#  'plenario': 3640,
#  'afirmando': 199,
#  'gerais': 2257,
#  'colunistas': 971,
#  'cartel': 797,
#  '1a': 18,
#  'farias': 2040,
#  'supostamente': 4521,
#  'sabia': 4279,
#  'punicao': 3937,
#  'costa': 1201,
#  'ainda': 227,
#  'horario': 2378,
#  'sobre': 4453,
#  'veto': 4897,
#  'afastada': 189,
#  'parece': 3452,
#  'simbolos': 4424,
#  'adultos': 178,
#  'pichadores': 3622,
#  'ingenuidade': 2531,
#  'modo': 3116,
#  'destaque': 1475,
#  'desvio': 1484,
#  'igrejas': 2422,
#  'vimos': 4916,
#  'escalao': 1805,
#  'evangelica': 1922,
#  'lidera': 2828,
#  'dando': 1300,
#  'russia': 4268,
#  'levado': 2803,
#  'stalin': 4491,
#  'matou': 2994,
#  'nelson': 3225,
#  'relevantes': 4125,
#  'proletariado': 3862,
#  'cometer': 997,
#  'ministerios': 3097,
#  'perfil': 3568,
#  'porte': 3687,
#  'termina': 4619,
#  'cultura': 1276,
#  'atacou': 482,
#  'mala': 2916,
#  'escolhido': 1819,
#  'paulo': 3503,
#  'eletrobras': 1693,
#  'orelha': 3378,
#  'culpar': 1273,
#  'felipe': 2082,
#  'tentara': 4601,
#  'geddel': 2246,
#  'tipos': 4651,
#  'atender': 491,
#  'deviam': 1507,
#  'convoca': 1172,
#  'ideologica': 2414,
#  'evidente': 1929,
#  'primeiros': 3807,
#  'gayzistas': 2245,
#  'negativa': 3213,
#  'representantes': 4150,
#  'lutando': 2892,
#  'setembro': 4400,
#  'ganho': 2227,
#  'maneira': 2930,
#  'longo': 2872,
#  'protege': 3891,
#  'america': 302,
#  'amazona': 294,
#  'fa': 1989,
#  '2012': 29,
#  'jornalivre': 2692,
#  'recessao': 4045,
#  'duque': 1648,
#  'enfim': 1742,
#  'unido': 4787,
#  'destes': 1479,
#  'aberracao': 85,
#  'morais': 3130,
#  'muita': 3169,
#  'questao': 3975,
#  'ganham': 2224,
#  'bernardo': 637,
#  'urgente': 4795,
#  'segurancas': 4346,
#  'outra': 3397,
#  'fronteiras': 2194,
#  'pior': 3626,
#  'tendem': 4592,
#  'congresso': 1078,
#  '000': 1,
#  'delirio': 1384,
#  'histeria': 2353,
#  'juiz': 2703,
#  'algo': 254,
#  'prepara': 3768,
#  'corrupto': 1196,
#  'pacote': 3409,
#  'apelo': 366,
#  'sentir': 4373,
#  'concluiu': 1048,
#  'praticados': 3731,
#  'psicopatas': 3918,
#  'convocacao': 1173,
#  'atacam': 479,
#  'protecao': 3890,
#  '500': 67,
#  'feminista': 2085,
#  'atraso': 515,
#  'impossivel': 2463,
#  'dupla': 1646,
#  'ironia': 2629,
#  'envia': 1782,
#  'cristiana': 1242,
#  'negocia': 3215,
#  'assinou': 467,
#  '36': 57,
#  've': 4847,
#  'inimigos': 2545,
#  'dano': 1303,
#  'anastasia': 320,
#  'youtube': 4991,
#  'cinema': 901,
#  'compreender': 1028,
#  'conversa': 1165,
#  'acusar': 148,
#  'exame': 1935,
#  'mail': 2909,
#  'economica': 1658,
#  'gleisi': 2270,
#  'cai': 728,
#  'momentos': 3120,
#  'passe': 3487,
#  'rejeita': 4107,
#  'esquemas': 1864,
#  'levantamento': 2806,
#  'levaram': 2808,
#  'aplicar': 373,
#  'morto': 3142,
#  'estupros': 1912,
#  'rousseff': 4262,
#  'pragmatismo': 3727,
#  'hacker': 2331,
#  'vindo': 4918,
#  'deixara': 1370,
#  'huck': 2385,
#  'conflitos': 1073,
#  'suspeitas': 4539,
#  'marcelo': 2958,
#  'homicidio': 2364,
#  'esconde': 1820,
#  'cometido': 1000,
#  'responde': 4170,
#  'pagina': 3421,
#  'federal': 2071,
#  'terra': 4623,
#  'tipica': 4648,
#  'acusado': 145,
#  'inaceitavel': 2472,
#  'alternativas': 280,
#  'finge': 2131,
#  'contexto': 1142,
#  'povo': 3720,
#  'medo': 3011,
#  'expulsao': 1980,
#  'oab': 3279,
#  'dirceu': 1547,
#  'fundamental': 2212,
#  'civis': 921,
#  'velorio': 4858,
#  'testemunha': 4637,
#  'define': 1356,
#  'joga': 2673,
#  'absurdas': 101,
#  'bolso': 678,
#  'niveis': 3244,
#  'tradicionais': 4711,
#  'relevante': 4124,
#  'normais': 3257,
#  'confronto': 1075,
#  'ficado': 2099,
#  'zanin': 4992,
#  'tj': 4660,
#  'esperto': 1855,
#  'governoha': 2294,
#  'objecao': 3282,
#  'afeta': 193,
#  'colaboracao': 952,
#  'julgado': 2708,
#  'argentino': 423,
#  'patetico': 3495,
#  'contribuicao': 1159,
#  'padroes': 3414,
#  'petistas': 3608,
#  'perda': 3556,
#  'agredir': 216,
#  '65': 75,
#  'movimentos': 3157,
#  'suspenso': 4547,
#  'inglaterra': 2533,
#  'embora': 1704,
#  'palocci': 3434,
#  'psd': 3912,
#  'to': 4661,
#  'capaz': 768,
#  'sede': 4329,
#  'outubro': 3401,
#  'ocorrido': 3317,
#  'venha': 4872,
#  'haddad': 2332,
#  'assalto': 452,
#  'retira': 4188,
#  'artistas': 448,
#  'vira': 4928,
#  'quer': 3967,
#  'tolerar': 4669,
#  'recurso': 4069,
#  'oposta': 3370,
#  'ocasiao': 3306,
#  'dilma': 1538,
#  'juridico': 2719,
#  'wagner': 4979,
#  'totalitaria': 4694,
#  'greve': 2315,
#  'seguiu': 4341,
#  'alvo': 288,
#  'moro': 3136,
#  'jair': 2648,
#  'norte': 3260,
#  'chamado': 855,
#  'palavras': 3431,
#  'leia': 2775,
#  'desse': 1473,
#  'sala': 4294,
#  'previsao': 3801,
#  'publicos': 3933,
#  'evidencia': 1927,
#  'tradicao': 4710,
#  'enviado': 1784,
#  'rapido': 4002,
#  'mentalidade': 3038,
#  'lancados': 2749,
#  'facilidade': 2001,
#  'ir': 2621,
#  'curitiba': 1288,
#  'forcas': 2157,
#  'lembrar': 2786,
#  'favoraveis': 2053,
#  'desiste': 1458,
#  'atendimento': 492,
#  'dama': 1299,
#  'vence': 4862,
#  'publicas': 3930,
#  'empreendimento': 1716,
#  'ameaca': 299,
#  'contradicao': 1150,
#  'justificativa': 2728,
#  'sequencia': 4375,
#  'principio': 3812,
#  'criticam': 1250,
#  'lutar': 2893,
#  'comecaram': 980,
#  'convite': 1170,
#  'note': 3264,
#  'perigoso': 3577,
#  'puramente': 3942,
#  'conservadorismo': 1107,
#  'etica': 1916,
#  'trf4': 4743,
#  'herman': 2345,
#  'pronto': 3871,
#  'votar': 4970,
#  'selecao': 4350,
#  'prejudica': 3754,
#  'israel': 2639,
#  'parecia': 3455,
#  'boechat': 668,
#  'iluminismo': 2431,
#  'fevereiro': 2094,
#  '51': 68,
#  'figuras': 2114,
#  'especialista': 1840,
#  'elogia': 1700,
#  'sr': 4490,
#  'forum': 2169,
#  'destruiu': 1483,
#  'figura': 2113,
#  'precisamos': 3741,
#  'liderancas': 2830,
#  'pronta': 3870,
#  'percebe': 3551,
#  'reclamacoes': 4051,
#  'saiba': 4287,
#  'apresentadora': 401,
#  'manifestantes': 2936,
#  'tera': 4611,
#  'bobagem': 666,
#  'internet': 2589,
#  'facebook': 1997,
#  'humilhado': 2398,
#  'criada': 1223,
#  'entidade': 1766,
#  'reclamou': 4054,
#  'framework': 2177,
#  'previsto': 3803,
#  'andrea': 327,
#  'citam': 913,
#  'libertacao': 2821,
#  'interferencia': 2579,
#  'anti': 341,
#  'cantora': 764,
#  'nazistas': 3204,
#  'aguarda': 224,
#  'informa': 2526,
#  'finalmente': 2126,
#  'irmao': 2627,
#  'tv': 4769,
#  'sexual': 4405,
#  'cadeira': 725,
#  'justifica': 2726,
#  'sobe': 4451,
#  'direitistas': 1552,
#  'agressor': 220,
#  'profundo': 3852,
#  'faziam': 2063,
#  'obrigacao': 3289,
#  'praticar': 3733,
#  'odio': 3323,
#  'unico': 4784,
#  'socialismo': 4458,
#  'leitores': 2780,
#  'legislativo': 2770,
#  'curiosamente': 1286,
#  'investigada': 2612,
#  'aliancas': 266,
#  'eletronica': 1694,
#  'feitas': 2077,
#  'dezenas': 1512,
#  'diz': 1614,
#  'lancando': 2751,
#  'bahia': 573,
#  'diretamente': 1556,
#  'kim': 2737,
#  'lenin': 2794,
#  'usando': 4804,
#  'supostas': 4522,
#  'espacos': 1838,
#  'encontros': 1738,
#  'autoridade': 547,
#  'robin': 4237,
#  'taco': 4552,
#  'rocha': 4238,
#  'voo': 4964,
#  'questionada': 3977,
#  'passagens': 3481,
#  'francine': 2181,
#  'agricultura': 221,
#  'detona': 1493,
#  'news': 3240,
#  'fara': 2035,
#  'candidatura': 761,
#  'ancelmo': 321,
#  'atuais': 521,
#  'entram': 1770,
#  'atos': 511,
#  'cbn': 821,
#  'caindo': 730,
#  'df': 1513,
#  'adiamento': 160,
#  'escritorio': 1833,
#  'guerras': 2323,
#  'avisa': 568,
#  '41': 63,
#  'passam': 3482,
#  'bla': 650,
#  'querem': 3968,
#  'araujo': 419,
#  'investidores': 2608,
#  'popularidade': 3680,
#  'codigo': 944,
#  'investigar': 2617,
#  'policiais': 3669,
#  'comparecer': 1012,
#  'braco': 687,
#  'al': 233,
#  'penas': 3538,
#  'recorrer': 4064,
#  'definitivamente': 1363,
#  'comparar': 1011,
#  'graca': 2296,
#  'representacao': 4147,
#  'apresenta': 396,
#  'seguido': 4334,
#  'relacoes': 4117,
#  'saem': 4283,
#  'transparencia': 4725,
#  'ateista': 488,
#  'buscas': 713,
#  'atitudes': 501,
#  'noticias': 3266,
#  'convocar': 1174,
#  'proibido': 3857,
#  'donald': 1634,
#  'determinado': 1490,
#  'publicou': 3934,
#  'vivem': 4952,
#  'irritado': 2634,
#  'anterior': 337,
#  'alegacao': 240,
#  'justamente': 2724,
#  'dar': 1311,
#  'defendendo': 1346,
#  'empresarios': 1725,
#  'cafe': 727,
#  'atingiu': 499,
#  'peticao': 3605,
#  'lider': 2827,
#  'ligado': 2837,
#  'julgamento': 2709,
#  'trabalhar': 4705,
#  'demitir': 1392,
#  'alguem': 255,
#  'verdadeiras': 4880,
#  'proibe': 3855,
#  'pai': 3426,
#  'calunia': 741,
#  'extremum': 1988,
#  'nesse': 3232,
#  'comunista': 1037,
#  'comprovar': 1031,
#  'qualquer': 3950,
#  '16': 14,
#  'juridica': 2718,
#  'consequencias': 1103,
#  ...}

# %%
len(train_data.vocabulary_)
# Out:
# 5000

# %%
# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features = vectorizer.fit_transform(clean_train_news)

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_data_features = train_data_features.toarray()

# %%
train_data_features.shape
# Out:
# (31760, 5000)

# %% [markdown]
# ### Ordenando as palavras no dataset completo

# %%
# Create the defaultdict: total_word_count
total_word_count = defaultdict(int)
for word_id, word_count in itertools.chain.from_iterable(corpus):
    total_word_count[word_id] += word_count

# Create a sorted list from the defaultdict: sorted_word_count
sorted_word_count = sorted(total_word_count.items(), key=lambda w: w[1], reverse=True) 

# Print the top 5 words across all documents alongside the count
for word_id, word_count in sorted_word_count[:5]:
    print(dictionary.get(word_id), word_count)
# Out:
# nao 36043
# ha 13381
# diz 11913
# contra 10390
# politica 10339

# %% [markdown]
# ##### Agora, iremos desenvolver as pontuações e pesos para cara word afim de normalizar a contagem de cada uma delas.

# %% [markdown]
# Primeiro, com o modelo gensim

# %%
from gensim.models.tfidfmodel import TfidfModel

# %%
tfidf = TfidfModel(corpus)

# %%
doc = corpus[0]
tfidf_weights = tfidf[doc]
sorted_tfidf_weights = sorted(tfidf_weights, key=lambda w: w[1], reverse=True)

# Print the top 5 weighted words
for term_id, weight in sorted_tfidf_weights[:5]:
    print(dictionary.get(term_id), weight)
# Out:
# elogia 0.5088339957508835
# autoridade 0.3885133389627161
# abuso 0.3857701622995602
# aprovado 0.37537846608534314
# senadoha 0.28045374119674116

# %% [markdown]
# Agora, com scikit-learn

# %%
from sklearn.feature_extraction.text import TfidfVectorizer 
# Initialize a TfidfVectorizer object: tfidf_vectorizer
tfidf_vectorizer = TfidfVectorizer(analyzer = "word", \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000)  



tfidf_train_vocab = tfidf_vectorizer.fit(clean_train_news)
tfidf_train_vocab.vocabulary_
# Out:
# {'tona': 4678,
#  'economia': 1657,
#  'sabiam': 4280,
#  'atividades': 503,
#  'salarios': 4297,
#  'casos': 804,
#  'textos': 4643,
#  'dessas': 1472,
#  'critica': 1248,
#  'humanas': 2388,
#  'feia': 2073,
#  'inacreditavel': 2474,
#  'gosto': 2287,
#  'inacio': 2473,
#  'aprovacao': 407,
#  'irma': 2626,
#  'fenomeno': 2087,
#  'comite': 1007,
#  'privada': 3821,
#  'cruel': 1258,
#  'arrogante': 437,
#  'reducao': 4076,
#  'villa': 4915,
#  'janeiro': 2654,
#  'focado': 2147,
#  'aplica': 369,
#  'existencia': 1961,
#  'revoltados': 4216,
#  'seguintes': 4338,
#  'valor': 4834,
#  'totalitarismo': 4698,
#  'desembargador': 1452,
#  'suplicy': 4518,
#  'tornaram': 4686,
#  'inevitavel': 2518,
#  'entendeu': 1763,
#  'sentiu': 4374,
#  'modelos': 3111,
#  'pgr': 3616,
#  'digo': 1536,
#  'especifico': 1845,
#  'pmdb': 3644,
#  'nacional': 3188,
#  'agentes': 208,
#  'vermelho': 4893,
#  'pontos': 3676,
#  'lewandowski': 2811,
#  'enganar': 1745,
#  'aviso': 569,
#  'margem': 2964,
#  'honestidade': 2372,
#  'desta': 1474,
#  'racismo': 3992,
#  'juca': 2698,
#  'solto': 4477,
#  'procuradores': 3839,
#  'execucao': 1944,
#  'lope': 2873,
#  'mtst': 3163,
#  'cena': 827,
#  'dizia': 1618,
#  'marxistas': 2983,
#  'apoiado': 377,
#  'protestar': 3894,
#  'agressao': 217,
#  'dirigentes': 1564,
#  'democratica': 1396,
#  'irracionais': 2630,
#  'permanecer': 3581,
#  'tentativas': 4604,
#  'recife': 4048,
#  'chilique': 881,
#  'polemicas': 3667,
#  'rodrigo': 4240,
#  'definiu': 1364,
#  'aceitavel': 112,
#  'garcia': 2232,
#  '37': 58,
#  'inves': 2607,
#  'desmascara': 1461,
#  '2008': 25,
#  'abandonar': 84,
#  'claudia': 928,
#  'entrada': 1769,
#  'maus': 2997,
#  'apenas': 367,
#  'acusacoes': 143,
#  'relacionadas': 4113,
#  'independencia': 2495,
#  'gosta': 2283,
#  'esperar': 1851,
#  'peemedebista': 3530,
#  '14': 11,
#  'pinheiro': 3625,
#  'jogado': 2675,
#  'criminosos': 1236,
#  'maranhao': 2953,
#  'antecipada': 335,
#  'administrativa': 166,
#  'caminho': 748,
#  'militar': 3085,
#  'colombia': 968,
#  'parte': 3460,
#  'censurar': 831,
#  'recuo': 4066,
#  'programas': 3854,
#  'refutar': 4091,
#  'fonte': 2153,
#  'excelente': 1940,
#  'daqueles': 1308,
#  'obama': 3281,
#  'paula': 3501,
#  'ingenuo': 2532,
#  'problema': 3829,
#  'entrevistas': 1780,
#  'caluniosa': 742,
#  'negativo': 3214,
#  'documento': 1622,
#  'facam': 1994,
#  'perdido': 3564,
#  'impunidade': 2469,
#  'colocar': 966,
#  'senado': 4356,
#  'alegando': 243,
#  'criou': 1237,
#  'investigadores': 2615,
#  'si': 4410,
#  'revisao': 4211,
#  'aqui': 417,
#  'ibope': 2402,
#  'comemoracao': 984,
#  'gasta': 2238,
#  'demonstrar': 1406,
#  'colocou': 967,
#  'reforca': 4084,
#  'trabalham': 4703,
#  'pf': 3615,
#  'sugere': 4503,
#  'obrigado': 3291,
#  'aulas': 534,
#  'investir': 2620,
#  'leitao': 2777,
#  'volta': 4958,
#  'distritao': 1590,
#  'pesquisas': 3598,
#  'sujo': 4511,
#  'rejeitar': 4109,
#  'ta': 4551,
#  'mineiro': 3092,
#  'entretanto': 1778,
#  'craig': 1211,
#  'papel': 3438,
#  'iguais': 2423,
#  'darwinismo': 1314,
#  'reino': 4105,
#  'volume': 4962,
#  'presidencial': 3775,
#  'empreiteiras': 1720,
#  'assista': 468,
#  'correcao': 1188,
#  'valores': 4835,
#  'taxon': 4570,
#  'discordar': 1565,
#  'hipocrisia': 2350,
#  'buscar': 712,
#  'governos': 2295,
#  'totalitarios': 4697,
#  'indicadores': 2503,
#  'fundamentais': 2211,
#  'declarado': 1337,
#  'publicacao': 3925,
#  'quorum': 3988,
#  'imediato': 2440,
#  'completamente': 1016,
#  'sintese': 4438,
#  'chorar': 885,
#  'igualdade': 2425,
#  'romero': 4245,
#  'honestos': 2374,
#  'fechado': 2067,
#  'junior': 2715,
#  'david': 1317,
#  'colocando': 965,
#  'obras': 3287,
#  'valer': 4828,
#  'apanhar': 355,
#  'vender': 4866,
#  'zona': 4997,
#  'minimo': 3093,
#  'secretario': 4326,
#  'detido': 1492,
#  'discute': 1572,
#  'turismo': 4766,
#  'legitimidade': 2772,
#  'clube': 936,
#  'declara': 1334,
#  'g1': 2219,
#  'evolucao': 1932,
#  'ultimos': 4776,
#  'senso': 4366,
#  'logica': 2867,
#  'repasse': 4138,
#  'perto': 3594,
#  'danos': 1304,
#  'hoffmann': 2358,
#  'profissional': 3851,
#  'votaram': 4972,
#  'informado': 2529,
#  'realizado': 4023,
#  'acreditam': 136,
#  'coracao': 1179,
#  'liberdade': 2820,
#  'propos': 3879,
#  'agenda': 206,
#  'saul': 4320,
#  'richard': 4221,
#  'atibaia': 496,
#  'configura': 1067,
#  'prazo': 3736,
#  'roubo': 4261,
#  'desmascarar': 1463,
#  'governista': 2291,
#  'aceite': 113,
#  'jato': 2661,
#  'acordo': 132,
#  'ninguem': 3242,
#  'instancia': 2553,
#  'hasselmann': 2335,
#  'site': 4443,
#  'doria': 1638,
#  'receberam': 4035,
#  'quadro': 3946,
#  'laudo': 2757,
#  'narrativa': 3195,
#  'nisso': 3243,
#  'mostram': 3145,
#  'ministra': 3098,
#  'bilionario': 646,
#  'censura': 830,
#  'dimensao': 1540,
#  'agredida': 214,
#  'norma': 3256,
#  'pm': 3643,
#  'patetica': 3494,
#  'demolir': 1401,
#  'embustes': 1706,
#  'rouanet': 4259,
#  'tse': 4759,
#  'parcela': 3449,
#  'nazista': 3203,
#  'verdadeiros': 4882,
#  'implica': 2456,
#  'risco': 4230,
#  'requiao': 4159,
#  'eliseu': 1698,
#  'veiculos': 4850,
#  'delacoes': 1375,
#  'miguel': 3072,
#  'facil': 2000,
#  'ato': 508,
#  'sabendo': 4277,
#  'embuste': 1705,
#  'preco': 3745,
#  'impor': 2458,
#  'saco': 4281,
#  'observem': 3295,
#  'corrente': 1190,
#  'intuito': 2600,
#  'falha': 2017,
#  'existir': 1962,
#  'gayzista': 2244,
#  'daqui': 1309,
#  'expoe': 1973,
#  'totalmente': 4699,
#  'empresa': 1722,
#  'absoluta': 96,
#  'manifesto': 2938,
#  'programa': 3853,
#  'temer': 4587,
#  'collor': 962,
#  'outras': 3398,
#  'ante': 334,
#  'colegio': 957,
#  'alvos': 290,
#  'indicacao': 2501,
#  'revista': 4212,
#  'clique': 935,
#  'flavio': 2144,
#  'conselho': 1099,
#  'equivoco': 1797,
#  'esquerda': 1865,
#  'matar': 2988,
#  'wesley': 4984,
#  'recuperacao': 4067,
#  'emenda': 1707,
#  'pensa': 3540,
#  'atrair': 512,
#  'conversas': 1167,
#  'defender': 1347,
#  'envio': 1786,
#  'fachin': 1999,
#  'totalitarias': 4695,
#  'recibos': 4047,
#  'vantagem': 4839,
#  'gerar': 2262,
#  'moderna': 3115,
#  'doutrina': 1639,
#  'desarmamento': 1438,
#  'rotula': 4253,
#  'usadas': 4800,
#  'divisao': 1606,
#  'produto': 3843,
#  '150': 13,
#  'junto': 2717,
#  'picciani': 3621,
#  'condenados': 1056,
#  'espere': 1853,
#  'milicianos': 3078,
#  'pau': 3500,
#  'guido': 2324,
#  'justa': 2723,
#  'tao': 4563,
#  'fgts': 2096,
#  'lucio': 2882,
#  'bilhao': 644,
#  'responsaveis': 4174,
#  'massa': 2985,
#  'bruno': 704,
#  'realizacao': 4021,
#  'indignado': 2510,
#  'parcial': 3451,
#  'aspecto': 450,
#  'refuta': 4089,
#  'sul': 4513,
#  'atualmente': 525,
#  'adequado': 156,
#  'terminar': 4620,
#  'adeptos': 153,
#  'meia': 3012,
#  'pobre': 3646,
#  'revela': 4206,
#  'brasileiras': 695,
#  'manobras': 2942,
#  'marxista': 2982,
#  'soares': 4449,
#  'pimentel': 3624,
#  'russomanno': 4270,
#  'elogios': 1701,
#  'rebater': 4027,
#  'vinda': 4917,
#  'ocorre': 3308,
#  'pps': 3722,
#  'queiram': 3964,
#  'lideranca': 2829,
#  'autorizou': 552,
#  'autoriza': 550,
#  'maio': 2910,
#  'reunem': 4200,
#  'the': 4644,
#  'divulgada': 1609,
#  'lavagem': 2760,
#  'privilegiado': 3826,
#  'ocupar': 3319,
#  'cobra': 941,
#  'aumentam': 536,
#  'falacias': 2009,
#  'recomenda': 4055,
#  'assume': 472,
#  'randolfe': 3999,
#  'neve': 3238,
#  'acusa': 141,
#  'possui': 3706,
#  'expressar': 1978,
#  'lancou': 2753,
#  'decreta': 1341,
#  'prb': 3737,
#  'chegando': 875,
#  'diretorio': 1562,
#  'juntar': 2716,
#  'religiosos': 4131,
#  'proprio': 3887,
#  'apoiam': 379,
#  'sangue': 4308,
#  'tai': 4553,
#  'rebate': 4026,
#  'relacionado': 4114,
#  'perderam': 3562,
#  'calote': 740,
#  'formula': 2163,
#  'olhar': 3340,
#  'escrevi': 1830,
#  'falo': 2020,
#  'ligados': 2838,
#  'mora': 3127,
#  'psol': 3921,
#  'comando': 974,
#  'anticorrupcao': 342,
#  'comecam': 978,
#  'ver': 4873,
#  'leo': 2795,
#  'oas': 3280,
#  'critico': 1254,
#  'dependem': 1421,
#  'considerado': 1110,
#  'feria': 2088,
#  'garante': 2229,
#  'catolicos': 813,
#  'exatamente': 1937,
#  'educacao': 1670,
#  'portaria': 3686,
#  'resolveram': 4166,
#  'negociacao': 3216,
#  'foco': 2149,
#  'idiota': 2416,
#  'inicio': 2541,
#  'protesto': 3895,
#  'pericia': 3574,
#  'cujo': 1268,
#  'extremamente': 1985,
#  'executiva': 1946,
#  'vontade': 4963,
#  'tornado': 4682,
#  'motivo': 3151,
#  'madrugada': 2902,
#  'miller': 3087,
#  'indice': 2505,
#  'cirurgia': 906,
#  'esconder': 1821,
#  'humanistas': 2392,
#  'procedimento': 3831,
#  'ouve': 3402,
#  'monopolio': 3122,
#  'tirania': 4654,
#  'falei': 2016,
#  'mentais': 3036,
#  'serem': 4380,
#  'obvio': 3305,
#  'rogerio': 4243,
#  'roda': 4239,
#  'ditadura': 1595,
#  'caravana': 779,
#  'marco': 2962,
#  'passar': 3484,
#  'postou': 3713,
#  'henrique': 2344,
#  'ridicularizar': 4225,
#  'aparentemente': 362,
#  'catraca': 814,
#  'marido': 2968,
#  'fake': 2006,
#  'cultural': 1278,
#  'atea': 486,
#  'desempenho': 1453,
#  'diante': 1517,
#  'estados': 1877,
#  '28': 45,
#  'citei': 916,
#  'comportamental': 1022,
#  'coerente': 948,
#  'eletronicas': 1695,
#  'abrir': 94,
#  'exagero': 1934,
#  'moraes': 3129,
#  'radicais': 3995,
#  'pressionado': 3785,
#  '10': 6,
#  'documentos': 1623,
#  'guarda': 2320,
#  'simplesmente': 4428,
#  'sairam': 4290,
#  'ademais': 151,
#  'souza': 4486,
#  '00': 0,
#  'nogueira': 3248,
#  'indicia': 2506,
#  'faltou': 2027,
#  'validade': 4832,
#  'pragmatico': 3726,
#  'eduardo': 1669,
#  'desonesto': 1466,
#  'discutido': 1574,
#  'york': 4989,
#  'esforcos': 1835,
#  'rotular': 4256,
#  'curioso': 1287,
#  'coronel': 1182,
#  'britanico': 703,
#  'salvador': 4301,
#  'tomam': 4674,
#  'crer': 1218,
#  'maluco': 2919,
#  'unica': 4782,
#  'cassado': 806,
#  'cairam': 732,
#  'chantagem': 863,
#  'votacoes': 4967,
#  'militancia': 3082,
#  'dificuldades': 1530,
#  'pequeno': 3548,
#  'meios': 3014,
#  'queria': 3972,
#  'cientifico': 896,
#  'mudanca': 3165,
#  'pbh': 3508,
#  'lima': 2839,
#  'maiores': 2912,
#  'denuncia': 1411,
#  'uniao': 4781,
#  'optar': 3374,
#  'previdencia': 3800,
#  'aumento': 538,
#  'vanessa': 4838,
#  'indenizacao': 2494,
#  'prisao': 3819,
#  'missao': 3107,
#  'sindical': 4434,
#  'animal': 330,
#  'pleno': 3641,
#  'esforco': 1834,
#  'francisco': 2182,
#  'expor': 1974,
#  'estatuto': 1890,
#  'blogueiro': 657,
#  'licitacao': 2825,
#  'situacoes': 4446,
#  'milhares': 3076,
#  'acho': 122,
#  'linhas': 2851,
#  'pura': 3941,
#  'simulacao': 4429,
#  'seguro': 4347,
#  'cotidiano': 1205,
#  'ilegal': 2428,
#  'paragrafo': 3444,
#  'errou': 1802,
#  'mentiu': 3048,
#  'partidos': 3473,
#  'todos': 4666,
#  '19': 17,
#  'cidadania': 888,
#  'aceitacao': 110,
#  'meritos': 3056,
#  'psdb': 3913,
#  'jogou': 2682,
#  'dignidade': 1534,
#  'envolvido': 1790,
#  '26': 43,
#  'paginas': 3422,
#  'concedeu': 1040,
#  'negro': 3223,
#  'eleger': 1681,
#  'go': 2274,
#  'autoritarismo': 549,
#  'ontem': 3352,
#  'trouxeram': 4754,
#  'baiano': 574,
#  'familia': 2028,
#  'percebido': 3554,
#  'maquina': 2951,
#  'trabalhadores': 4702,
#  'salas': 4298,
#  'complica': 1019,
#  'legislacao': 2768,
#  'visitar': 4938,
#  'plenario': 3640,
#  'afirmando': 199,
#  'gerais': 2257,
#  'colunistas': 971,
#  'cartel': 797,
#  '1a': 18,
#  'farias': 2040,
#  'supostamente': 4521,
#  'sabia': 4279,
#  'punicao': 3937,
#  'costa': 1201,
#  'ainda': 227,
#  'horario': 2378,
#  'sobre': 4453,
#  'veto': 4897,
#  'afastada': 189,
#  'parece': 3452,
#  'simbolos': 4424,
#  'adultos': 178,
#  'pichadores': 3622,
#  'ingenuidade': 2531,
#  'modo': 3116,
#  'destaque': 1475,
#  'desvio': 1484,
#  'igrejas': 2422,
#  'vimos': 4916,
#  'escalao': 1805,
#  'evangelica': 1922,
#  'lidera': 2828,
#  'dando': 1300,
#  'russia': 4268,
#  'levado': 2803,
#  'stalin': 4491,
#  'matou': 2994,
#  'nelson': 3225,
#  'relevantes': 4125,
#  'proletariado': 3862,
#  'cometer': 997,
#  'ministerios': 3097,
#  'perfil': 3568,
#  'porte': 3687,
#  'termina': 4619,
#  'cultura': 1276,
#  'atacou': 482,
#  'mala': 2916,
#  'escolhido': 1819,
#  'paulo': 3503,
#  'eletrobras': 1693,
#  'orelha': 3378,
#  'culpar': 1273,
#  'felipe': 2082,
#  'tentara': 4601,
#  'geddel': 2246,
#  'tipos': 4651,
#  'atender': 491,
#  'deviam': 1507,
#  'convoca': 1172,
#  'ideologica': 2414,
#  'evidente': 1929,
#  'primeiros': 3807,
#  'gayzistas': 2245,
#  'negativa': 3213,
#  'representantes': 4150,
#  'lutando': 2892,
#  'setembro': 4400,
#  'ganho': 2227,
#  'maneira': 2930,
#  'longo': 2872,
#  'protege': 3891,
#  'america': 302,
#  'amazona': 294,
#  'fa': 1989,
#  '2012': 29,
#  'jornalivre': 2692,
#  'recessao': 4045,
#  'duque': 1648,
#  'enfim': 1742,
#  'unido': 4787,
#  'destes': 1479,
#  'aberracao': 85,
#  'morais': 3130,
#  'muita': 3169,
#  'questao': 3975,
#  'ganham': 2224,
#  'bernardo': 637,
#  'urgente': 4795,
#  'segurancas': 4346,
#  'outra': 3397,
#  'fronteiras': 2194,
#  'pior': 3626,
#  'tendem': 4592,
#  'congresso': 1078,
#  '000': 1,
#  'delirio': 1384,
#  'histeria': 2353,
#  'juiz': 2703,
#  'algo': 254,
#  'prepara': 3768,
#  'corrupto': 1196,
#  'pacote': 3409,
#  'apelo': 366,
#  'sentir': 4373,
#  'concluiu': 1048,
#  'praticados': 3731,
#  'psicopatas': 3918,
#  'convocacao': 1173,
#  'atacam': 479,
#  'protecao': 3890,
#  '500': 67,
#  'feminista': 2085,
#  'atraso': 515,
#  'impossivel': 2463,
#  'dupla': 1646,
#  'ironia': 2629,
#  'envia': 1782,
#  'cristiana': 1242,
#  'negocia': 3215,
#  'assinou': 467,
#  '36': 57,
#  've': 4847,
#  'inimigos': 2545,
#  'dano': 1303,
#  'anastasia': 320,
#  'youtube': 4991,
#  'cinema': 901,
#  'compreender': 1028,
#  'conversa': 1165,
#  'acusar': 148,
#  'exame': 1935,
#  'mail': 2909,
#  'economica': 1658,
#  'gleisi': 2270,
#  'cai': 728,
#  'momentos': 3120,
#  'passe': 3487,
#  'rejeita': 4107,
#  'esquemas': 1864,
#  'levantamento': 2806,
#  'levaram': 2808,
#  'aplicar': 373,
#  'morto': 3142,
#  'estupros': 1912,
#  'rousseff': 4262,
#  'pragmatismo': 3727,
#  'hacker': 2331,
#  'vindo': 4918,
#  'deixara': 1370,
#  'huck': 2385,
#  'conflitos': 1073,
#  'suspeitas': 4539,
#  'marcelo': 2958,
#  'homicidio': 2364,
#  'esconde': 1820,
#  'cometido': 1000,
#  'responde': 4170,
#  'pagina': 3421,
#  'federal': 2071,
#  'terra': 4623,
#  'tipica': 4648,
#  'acusado': 145,
#  'inaceitavel': 2472,
#  'alternativas': 280,
#  'finge': 2131,
#  'contexto': 1142,
#  'povo': 3720,
#  'medo': 3011,
#  'expulsao': 1980,
#  'oab': 3279,
#  'dirceu': 1547,
#  'fundamental': 2212,
#  'civis': 921,
#  'velorio': 4858,
#  'testemunha': 4637,
#  'define': 1356,
#  'joga': 2673,
#  'absurdas': 101,
#  'bolso': 678,
#  'niveis': 3244,
#  'tradicionais': 4711,
#  'relevante': 4124,
#  'normais': 3257,
#  'confronto': 1075,
#  'ficado': 2099,
#  'zanin': 4992,
#  'tj': 4660,
#  'esperto': 1855,
#  'governoha': 2294,
#  'objecao': 3282,
#  'afeta': 193,
#  'colaboracao': 952,
#  'julgado': 2708,
#  'argentino': 423,
#  'patetico': 3495,
#  'contribuicao': 1159,
#  'padroes': 3414,
#  'petistas': 3608,
#  'perda': 3556,
#  'agredir': 216,
#  '65': 75,
#  'movimentos': 3157,
#  'suspenso': 4547,
#  'inglaterra': 2533,
#  'embora': 1704,
#  'palocci': 3434,
#  'psd': 3912,
#  'to': 4661,
#  'capaz': 768,
#  'sede': 4329,
#  'outubro': 3401,
#  'ocorrido': 3317,
#  'venha': 4872,
#  'haddad': 2332,
#  'assalto': 452,
#  'retira': 4188,
#  'artistas': 448,
#  'vira': 4928,
#  'quer': 3967,
#  'tolerar': 4669,
#  'recurso': 4069,
#  'oposta': 3370,
#  'ocasiao': 3306,
#  'dilma': 1538,
#  'juridico': 2719,
#  'wagner': 4979,
#  'totalitaria': 4694,
#  'greve': 2315,
#  'seguiu': 4341,
#  'alvo': 288,
#  'moro': 3136,
#  'jair': 2648,
#  'norte': 3260,
#  'chamado': 855,
#  'palavras': 3431,
#  'leia': 2775,
#  'desse': 1473,
#  'sala': 4294,
#  'previsao': 3801,
#  'publicos': 3933,
#  'evidencia': 1927,
#  'tradicao': 4710,
#  'enviado': 1784,
#  'rapido': 4002,
#  'mentalidade': 3038,
#  'lancados': 2749,
#  'facilidade': 2001,
#  'ir': 2621,
#  'curitiba': 1288,
#  'forcas': 2157,
#  'lembrar': 2786,
#  'favoraveis': 2053,
#  'desiste': 1458,
#  'atendimento': 492,
#  'dama': 1299,
#  'vence': 4862,
#  'publicas': 3930,
#  'empreendimento': 1716,
#  'ameaca': 299,
#  'contradicao': 1150,
#  'justificativa': 2728,
#  'sequencia': 4375,
#  'principio': 3812,
#  'criticam': 1250,
#  'lutar': 2893,
#  'comecaram': 980,
#  'convite': 1170,
#  'note': 3264,
#  'perigoso': 3577,
#  'puramente': 3942,
#  'conservadorismo': 1107,
#  'etica': 1916,
#  'trf4': 4743,
#  'herman': 2345,
#  'pronto': 3871,
#  'votar': 4970,
#  'selecao': 4350,
#  'prejudica': 3754,
#  'israel': 2639,
#  'parecia': 3455,
#  'boechat': 668,
#  'iluminismo': 2431,
#  'fevereiro': 2094,
#  '51': 68,
#  'figuras': 2114,
#  'especialista': 1840,
#  'elogia': 1700,
#  'sr': 4490,
#  'forum': 2169,
#  'destruiu': 1483,
#  'figura': 2113,
#  'precisamos': 3741,
#  'liderancas': 2830,
#  'pronta': 3870,
#  'percebe': 3551,
#  'reclamacoes': 4051,
#  'saiba': 4287,
#  'apresentadora': 401,
#  'manifestantes': 2936,
#  'tera': 4611,
#  'bobagem': 666,
#  'internet': 2589,
#  'facebook': 1997,
#  'humilhado': 2398,
#  'criada': 1223,
#  'entidade': 1766,
#  'reclamou': 4054,
#  'framework': 2177,
#  'previsto': 3803,
#  'andrea': 327,
#  'citam': 913,
#  'libertacao': 2821,
#  'interferencia': 2579,
#  'anti': 341,
#  'cantora': 764,
#  'nazistas': 3204,
#  'aguarda': 224,
#  'informa': 2526,
#  'finalmente': 2126,
#  'irmao': 2627,
#  'tv': 4769,
#  'sexual': 4405,
#  'cadeira': 725,
#  'justifica': 2726,
#  'sobe': 4451,
#  'direitistas': 1552,
#  'agressor': 220,
#  'profundo': 3852,
#  'faziam': 2063,
#  'obrigacao': 3289,
#  'praticar': 3733,
#  'odio': 3323,
#  'unico': 4784,
#  'socialismo': 4458,
#  'leitores': 2780,
#  'legislativo': 2770,
#  'curiosamente': 1286,
#  'investigada': 2612,
#  'aliancas': 266,
#  'eletronica': 1694,
#  'feitas': 2077,
#  'dezenas': 1512,
#  'diz': 1614,
#  'lancando': 2751,
#  'bahia': 573,
#  'diretamente': 1556,
#  'kim': 2737,
#  'lenin': 2794,
#  'usando': 4804,
#  'supostas': 4522,
#  'espacos': 1838,
#  'encontros': 1738,
#  'autoridade': 547,
#  'robin': 4237,
#  'taco': 4552,
#  'rocha': 4238,
#  'voo': 4964,
#  'questionada': 3977,
#  'passagens': 3481,
#  'francine': 2181,
#  'agricultura': 221,
#  'detona': 1493,
#  'news': 3240,
#  'fara': 2035,
#  'candidatura': 761,
#  'ancelmo': 321,
#  'atuais': 521,
#  'entram': 1770,
#  'atos': 511,
#  'cbn': 821,
#  'caindo': 730,
#  'df': 1513,
#  'adiamento': 160,
#  'escritorio': 1833,
#  'guerras': 2323,
#  'avisa': 568,
#  '41': 63,
#  'passam': 3482,
#  'bla': 650,
#  'querem': 3968,
#  'araujo': 419,
#  'investidores': 2608,
#  'popularidade': 3680,
#  'codigo': 944,
#  'investigar': 2617,
#  'policiais': 3669,
#  'comparecer': 1012,
#  'braco': 687,
#  'al': 233,
#  'penas': 3538,
#  'recorrer': 4064,
#  'definitivamente': 1363,
#  'comparar': 1011,
#  'graca': 2296,
#  'representacao': 4147,
#  'apresenta': 396,
#  'seguido': 4334,
#  'relacoes': 4117,
#  'saem': 4283,
#  'transparencia': 4725,
#  'ateista': 488,
#  'buscas': 713,
#  'atitudes': 501,
#  'noticias': 3266,
#  'convocar': 1174,
#  'proibido': 3857,
#  'donald': 1634,
#  'determinado': 1490,
#  'publicou': 3934,
#  'vivem': 4952,
#  'irritado': 2634,
#  'anterior': 337,
#  'alegacao': 240,
#  'justamente': 2724,
#  'dar': 1311,
#  'defendendo': 1346,
#  'empresarios': 1725,
#  'cafe': 727,
#  'atingiu': 499,
#  'peticao': 3605,
#  'lider': 2827,
#  'ligado': 2837,
#  'julgamento': 2709,
#  'trabalhar': 4705,
#  'demitir': 1392,
#  'alguem': 255,
#  'verdadeiras': 4880,
#  'proibe': 3855,
#  'pai': 3426,
#  'calunia': 741,
#  'extremum': 1988,
#  'nesse': 3232,
#  'comunista': 1037,
#  'comprovar': 1031,
#  'qualquer': 3950,
#  '16': 14,
#  'juridica': 2718,
#  'consequencias': 1103,
#  ...}

# %%
train_data_features = tfidf_vectorizer.fit_transform(clean_train_news)

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_data_features = train_data_features.toarray()

# %%
train_data_features.shape
# Out:
# (31760, 5000)

# %% [markdown]
# # Analisando o teor das notícias (é fake ou não é???)

# %% [markdown]
# Para a primeira análise, decidimos usar Random Forest. Usaremos 100 árvores e 5000 top words, afim de otimizar o processo.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
# Initialize a Random Forest classifier with 100 trees
forest = RandomForestClassifier(n_estimators = 100) 

# Fit the forest to the training set, using the bag of words as 
# features and the status of news labels as the response variable
#
# This may take a few minutes to run
forest = forest.fit(train_data_features, news_train["target"] )

# %%
# Read the test data

# Verify that there are 25,000 rows and 2 columns
print(news_test.shape)
print(news_test.columns)

# Create an empty list and append the clean news one by one
num_news_test = len(news_test["title_summary"])
clean_test_news = [] 

for i in tqdm(range(0,num_news_test), total=num_news_test):
    clean_test_news.append( review_to_words( str(news_test["title_summary"].iloc[i]) ) )

# Get a bag of words for the test set, and convert to a numpy array
test_data_features = tfidf_vectorizer.transform(clean_test_news)
test_data_features = test_data_features.toarray()

# Use the random forest to make classification label predictions
result = forest.predict(test_data_features)

# Copy the results to a pandas dataframe with an "id" column and
# a "predict" column
output = pd.DataFrame( data={"site":news_test["veículo"], "title_summary":news_test["title_summary"], "target":news_test['target'], "target_predict":result} )
output
# Out:
#   0%|          | 33/15644 [00:00<00:47, 326.47it/s]
# (15644, 6)
# Index(['title', 'url', 'summary', 'veículo', 'target', 'title_summary'], dtype='object')
# 100%|██████████| 15644/15644 [00:50<00:00, 312.48it/s]
#                     site  target  target_predict  \
# 9218           hojeemdia       0               0
# 6         diariodobrasil       1               0
# 7377                  g1       0               0
# 2138          jornalivre       1               1
# 6200                  g1       0               0
# 6392                  g1       0               0
# 4649   ceticismopolitico       1               1
# 3342                  g1       0               0
# 9940           hojeemdia       0               0
# 2245          jornalivre       1               1
# 6437                  g1       0               0
# 9148           hojeemdia       0               0
# 4992          jornalivre       1               1
# 227       diariodobrasil       1               0
# 12407                 g1       0               0
# 3863   ceticismopolitico       1               1
# 9746           hojeemdia       0               0
# 8909   Em virtude dos escândalos de corrupção, Petrob...
# 5532   Câmara aprova proposta de reforma trabalhista;...
# 6468   Notícia de que Trump reconheceu Jerusalém como...
# 5347   União tem surpresinha desagradável para Palocc...
# 8526   Veja os deputados do PSDB que votaram contra a...
# 7990   Aloysio Nunes diz, sobre Venezuela: “A repress...
# 14850  Na tribuna, senador do PT chama programa do PM...
# 3838   Jair Bolsonaro coloca a educação de lixeira do...
# 5882   Em entrevista, Meirelles expõe desmandos do go...
# 3133   Estudo do Ministério da Fazenda aponta: Brasil...
# 6475   Palocci deve expor escândalos da Receita Feder...
# 7873   Temer consultou ministros do STF e políticos s...
# 426    'Lava Jato' prende ex-gerente da Transpetro 'L...
# 903    Pedro Bial pergunta a Ney Matogrosso o que que...
# 9847   INSS é transferido do Ministério do Trabalho p...
# 7246   Denúncias de violência sexual contra mulheres ...
# 3060   PBH tenta reverter ‘perdas’ na reforma PBH ten...
# 962     Jornal americano faz guia de palavras para tu...
# 1250   O sádico David Rockefeller morreu Neste 20 de ...
# 6068   Mentira tem perna curta: ao contrário do que o...
# 8047   Sessão com Dilma bate recorde de audiência no ...
# 6108   Impacto na economia com reforma da Previdência...
# 5376   Notícia de que Trump reconheceu Jerusalém como...
# 2149   Aprovação da PEC 241 em segundo turno humilha ...
# 1791   'Fatura' de leilão das usinas da Cemig pode ir...
# 9892   Confira como foi a votação no Senado por parla...
# 4174   PT silencia sobre governos autoritários, diz e...
# 5166   Ministro Eliseu Padilha passa mal e é internad...
# 2988   Temer vai a jantar com deputados na véspera da...
# 3042   Em vídeo, Temer diz que criminosos serão respo...
#
# [15644 rows x 4 columns]

# %%
accuracy = metrics.accuracy_score(y_test, result)
accuracy
# Out:
# 0.98331628739452825

# %% [markdown]
# # Replicando o modelo na base do twitter

# %% [markdown]
# Decidimos filtrar a base com pessoas que retweetaram links diretos das notícias pela dificuldade em extrair os links dos próprios tweets.

# %% [markdown]
# ## Importação da base

# %%
base_twitter = pd.read_csv('data/metadescription.csv', sep=',')

# %% [markdown]
# Tratamento da base com as colunas que interessam para o modelo

# %%
base_twitter.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Meta title', 'Meta description'], dtype='object')

# %%
base_twitter['title_summary'] = base_twitter['Title'] + base_twitter['Meta title'] + base_twitter['Meta description']

# %%
base_twitter = base_twitter.drop('Unnamed: 0', axis=1)

# %%
base_twitter.head()
# Out:
#                                                Title  \
# 0  JM Cunha Santos: Mulher condenada por matar cã...
# 1  Cem anos depois, a Rússia ainda debate o comun...
# 2  Motociclista é encontrado morto em rodovia de ...
# 3  Sem Cueva, Dorival Junior faz mistério em esca...
# 4  Ex-governador de Mato Grosso do Sul é alvo de ...
#
#                                           Meta title  \
# 0  Mulher condenada por matar cães e gatos tem pe...
# 1  Cem anos depois, a Rússia ainda debate o comun...
# 2  Motociclista é encontrado morto em rodovia de ...
# 3  Sem Cueva, Dorival Junior faz mistério em esca...
# 4  Ex-governador de Mato Grosso do Sul é alvo de ...
#
#                                     Meta description  \
# 0     POR JUSSARA SOARES     O GLOBO             ...
# 1  A Rússia deixou de comemorar o 7 de novembro, ...
# 2  Segundo a polícia, as causas da morte do motoc...
# 3                                                ...
# 4  A investida tem como objetivo desbaratar uma s...
#
#                                        title_summary
# 0  JM Cunha Santos: Mulher condenada por matar cã...
# 1  Cem anos depois, a Rússia ainda debate o comun...
# 2  Motociclista é encontrado morto em rodovia de ...
# 3  Sem Cueva, Dorival Junior faz mistério em esca...
# 4  Ex-governador de Mato Grosso do Sul é alvo de ...

# %% [markdown]
# #### Usando o modelo na base

# %%
# Read the twitter data

# Verify that there are 25,000 rows and 2 columns
print(base_twitter.shape)
print(base_twitter.columns)

# Create an empty list and append the clean news one by one
num_news_twitter = len(base_twitter["title_summary"])
clean_news_twitter = [] 

for i in tqdm(range(0,num_news_twitter), total=num_news_twitter):
    clean_news_twitter.append( review_to_words( str(base_twitter["title_summary"].iloc[i]) ) )

# Get a bag of words for the test set, and convert to a numpy array
test_data_features = tfidf_vectorizer.transform(clean_news_twitter)
test_data_features = test_data_features.toarray()

# Use the random forest to make classification label predictions
result = forest.predict(test_data_features)

# Copy the results to a pandas dataframe with an "id" column and
# a "predict" column
output = pd.DataFrame( data={"title_summary":base_twitter["title_summary"], "target_predict":result} )
output
# Out:
#   5%|▌         | 30/599 [00:00<00:01, 297.65it/s]
# (599, 4)
# Index(['Title', 'Meta title', 'Meta description', 'title_summary'], dtype='object')
# 100%|██████████| 599/599 [00:02<00:00, 295.31it/s]
#      target_predict                                      title_summary
# 0                 0  JM Cunha Santos: Mulher condenada por matar cã...
# 1                 0  Cem anos depois, a Rússia ainda debate o comun...
# 2                 0  Motociclista é encontrado morto em rodovia de ...
# 3                 0  Sem Cueva, Dorival Junior faz mistério em esca...
# 4                 0  Ex-governador de Mato Grosso do Sul é alvo de ...
# 5                 0  Runtime ErrorPágina sem meta titlePágina sem m...
# 6                 0  \r\nArtigo: 'A coragem é viral', diz ativista ...
# 7                 0                                                NaN
# 8                 0  \r\nAs Minhas Receitas: Caldeirada de Borrego ...
# 9                 0  \r\nFinanças rejeita criação de cargos em secr...
# 10                0  Defesa Civil emite alerta de inundação, desliz...
# 11                0  403 ForbiddenPágina sem meta titlePágina sem m...
# 12                0  Tribunal de Justiça do Estado da BahiaPágina s...
# 13                0  Professor Flávio Tartuce -  Direito Civil: XI ...
# 14                0  15° FÓRUM DE CERTIFICAÇÃO DIGITAL- NOVAS NORMA...
# 15                1  Lojas demoram até 70 dias para entregar móveis...
# 16                0  Bahia Notícias / Notícia / Operação Fraternos:...
# 17                0  maringa.odiario.comPágina sem meta titlePágina...
# 18                0   Taylor Swift | Reputation pode não ser dispon...
# 19                1  Carolina Ferraz abre processo trabalhista cont...
# 20                0  Carro bate em poste na Linha Verde e passageir...
# 21                1  Blog do EsmaelRio de Janeiro governado da cade...
# 22                0  Um guia para quem quer investir em Bitcoins – ...
# 23                0  Abel exalta Dourado e torce por artilharia: 'É...
# 24                0                                                NaN
# 25                0  Defesa de Lula diz que Moro desrespeita prerro...
# 26                0  maringa.odiario.comPágina sem meta titlePágina...
# 27                0  \r\n\tJapão espera que crise da Catalunha seja...
# 28                0  24 pessoas com fantasias de Dia das Bruxas mui...
# 29                0                                                NaN
# ..              ...                                                ...
# 569               0  Chay Suede fica marombado para viver novo pers...
# 570               0  Crise derruba agenda de shows de artistas no p...
# 571               0  Manifestantes chegam ao CAB e liberam trânsito...
# 572               0  Santos x Atlético-MG: o que vale a partida par...
# 573               1  VÍDEO: Diego Barbosa puxa camisa de Keno dentr...
# 574               0  Teatro Guarany recebe evento em homenagem ao u...
# 575               0    A entrega do Brasil avança: o desmonte do IN...
# 576               0  Unicamp aplica 1ª fase do vestibular 2018 para...
# 577               0  Empresa francesa processa o aeroporto do Galeã...
# 578               0  Galaxy S6 deve receber o Android 8.0 Oreo no f...
# 579               0  Polícia Militar apreende grande quantidade de ...
# 580               0  marian guimaraes emblog: Caldo Bom um portofól...
# 581               1  Bar que se vai para ler e lavar roupasBar que ...
# 582               0  Em longa fila, pais enfrentam chuva e reclamam...
# 583               0  Aprosoja Brasil: com baixa rentabilidade, come...
# 584               0  ARTIGO: Entender a realidade dos surdos ajuda ...
# 585               0  Pontos de Vistas: Bagas douradasPontos de Vist...
# 586               0  LOROTAS POLÍTICAS & VERDADES EFÊMERAS: DECISÃO...
# 587               0  Concurso Prefeitura - NiterÃ³i/RJ abre process...
# 588               0  ::: BLOG DO PAULINHO CASTRO :::::: O BICHO VAI...
# 589               0  Temer dará início à reforma ministerial - Jorn...
# 590               1  Mato Grosso Notícias | Enfermeira que aplicou ...
# 591               1  \r\n\tCâmara de Sintra aprova redução da taxa ...
# 592               0  Após denúncia, BOPE apreende 360 caixas de cig...
# 593               0  \r\n    Nove capitais têm esquema especial de ...
# 594               0  Jovem Pan Curitiba inaugura novo estúdio com p...
# 595               0  Troca na direção-geral da PF é uma 'temeridade...
# 596               0  O Fura-Redes: Obrigado Imperador!Obrigado Impe...
# 597               0  Submarino desaparecido não sofreu ataque exter...
# 598               0  Tecnologia permite prever a nota do Enem - POR...
#
# [599 rows x 2 columns]

# %%
output['target_predict'].value_counts()
# Out:
# 0    533
# 1     66
# Name: target_predict, dtype: int64

# %% [markdown]
# # Conclusão

# %% [markdown]
# De uma amostra de 599 links, temos 11,02% de FakeNews

# %%
fakenews_predict = output.filter(output['target_predict'] == 1)

# %%
fakenews_mask = output['target_predict'] == 1

# %%
output[~fakenews_mask].head()
# Out:
#    target_predict                                      title_summary
# 0               0  JM Cunha Santos: Mulher condenada por matar cã...
# 1               0  Cem anos depois, a Rússia ainda debate o comun...
# 2               0  Motociclista é encontrado morto em rodovia de ...
# 3               0  Sem Cueva, Dorival Junior faz mistério em esca...
# 4               0  Ex-governador de Mato Grosso do Sul é alvo de ...

# %%
output[fakenews_mask].head()
# Out:
#     target_predict                                      title_summary
# 15               1  Lojas demoram até 70 dias para entregar móveis...
# 19               1  Carolina Ferraz abre processo trabalhista cont...
# 21               1  Blog do EsmaelRio de Janeiro governado da cade...
# 44               1  \r\nJustiça determina que Marinha aceite inscr...
# 55               1  Graças a Messi, a Argentina chegou.E o Brasil ...
