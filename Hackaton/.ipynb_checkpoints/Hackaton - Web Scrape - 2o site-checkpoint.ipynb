# %%
import requests
from bs4 import BeautifulSoup

# %%
title_list = []
link_list = []
summary_list = []
datepost_list = []


##home = requests.get('https://jornalivre.com/').text
#soup = BeautifulSoup(home, 'html.parser')

#titles = soup.find_all('h1', {'class': 'entry-title'})
#summaries = soup.find_all('div', {'class': 'entry-summary'})
#datepost = soup.find_all('time', {'class': 'entry-date'})

#for title in titles:
 #   title_list.append(title.find('a').get_text())
  #  link_list.append(title.find('a').get('href'))

#for summary in summaries:
 #   summary_list.append(summary.find('p').get_text())

#for date in datepost:
 #   datepost_list.append(date.get('datetime'))

# %%
def ScrapeFakeNews(url):
    page = requests.get(url).text
    soup = BeautifulSoup(page,'html.parser')
    
    titles = soup.find_all('h1', {'class': 'entry-title'})
    summaries = soup.find_all('div', {'class': 'entry-summary'})
    datepost = soup.find_all('time', {'class': 'entry-date'})

    for title in titles:
        title_list.append(title.find('a').get_text())
        link_list.append(title.find('a').get('href'))

    for summary in summaries:
        summary_list.append(summary.find('p').get_text())

    for date in datepost:
        datepost_list.append(date.get('datetime'))

# %%
ScrapeFakeNews('https://jornalivre.com/')

# %%
from tqdm import tqdm

#x = 1
#paginas = 'https://jornalivre.com/page/' + str(x) +'/'
  
for x in tqdm(range(2,1513)):
    paginas = 'https://jornalivre.com/page/' + str(x) +'/'
    
    try: 
        ScrapeFakeNews(paginas)
    except (RuntimeError, TypeError, NameError):
        break
# Out:
#  16%|█▋        | 249/1511 [05:33<28:07,  1.34s/it]

# %%
# Out:
# ['https://jornalivre.com/2017/12/08/estudo-do-ministerio-da-fazenda-aponta-brasil-e-um-robin-hood-as-avessas/', 'https://jornalivre.com/2017/12/08/em-entrevista-meirelles-expoe-desmandos-do-governo-dilma-que-trouxeram-a-crise-economica/', 'https://jornalivre.com/2017/12/05/marcelo-odebrecht-volta-pra-casa-em-jatinho-particular/', 'https://jornalivre.com/2017/12/04/ex-secretario-da-saude-deixa-escapar-que-hematoma-de-garotinho-nao-e-compativel-com-taco-de-baseball/', 'https://jornalivre.com/2017/12/04/psdb-envergonhado-de-reformas-liberais-perde-apoio-do-governo-em-eleicao-presidencial/', 'https://jornalivre.com/2017/12/07/escandalo-vereadora-do-psol-monta-mega-esquema-de-corrupcao-e-desvio-de-verba-publica-diz-site-2/', 'https://jornalivre.com/2017/12/08/estudo-do-ministerio-da-fazenda-aponta-brasil-e-um-robin-hood-as-avessas/', 'https://jornalivre.com/2017/12/08/em-entrevista-meirelles-expoe-desmandos-do-governo-dilma-que-trouxeram-a-crise-economica/', 'https://jornalivre.com/2017/12/06/psdb-tenta-engambelar-eleitores-com-posicionamento-indefinido-sobre-reforma-da-previdencia/', 'https://jornalivre.com/2017/12/05/apos-dilma-entregar-inflacao-na-estratosfera-meirelles-consegue-baixar-os-precos-novamente/', 'https://jornalivre.com/2017/12/05/defesa-de-lula-leva-mais-uma-surra-no-trf-4/', 